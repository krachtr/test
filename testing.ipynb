# %%
from ipywidgets import GridspecLayout
import ipywidgets as widgets
from datetime import date, datetime
import numpy as np
import pandas as pd
import perspective
import psutil
import time

grid = GridspecLayout(25, 2)
grid.layout.height = 'auto'

# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html

a = widgets.BoundedIntText(
    value=100,
    min=50,
    max=10000,
    step=10,
    description='Text:',
    disabled=False
)
b= widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
c= widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False,
    indent=False
)
d=widgets.Valid(
    value=True,
    description='Valid!',
)
e=widgets.Dropdown(
    options=[('1',1), ('2',2), ('3',3)],
    value=2,
    description='Number:',
    disabled=False,
)
f=widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Pizza topping:',
    disabled=False
)
g=widgets.Select(
    options=['Linux', 'Windows', 'macOS'],
    value='macOS',
    # rows=10,
    description='OS:',
    disabled=False
)
h=widgets.SelectionSlider(
    options=['scrambled', 'sunny side up', 'poached', 'over easy'],
    value='sunny side up',
    description='I like my eggs ...',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True
)
import datetime
dates = [datetime.date(2015, i, 1) for i in range(1, 13)]
options = [(i.strftime('%b'), i) for i in dates]
i=widgets.SelectionRangeSlider(
    options=options,
    index=(0, 11),
    description='Months (2015)',
    disabled=False
)
j=widgets.ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
    #icons=['check'] * 3
)
k=widgets.SelectMultiple(
    options=['Apples', 'Oranges', 'Pears'],
    value=['Oranges'],
    #rows=10,
    description='Fruits',
    disabled=False
)
l=widgets.Text(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)
grid[0,0]=a
grid[1,0]=b
grid[2,0]=c
grid[3,0]=d
grid[0,1]=e
grid[1,1]=f
grid[2,1]=g
grid[3,1]=h
grid[4,0]=i
grid[10,0]=j
grid[4,1]=k
grid[10,1]=l

table = perspective.Table({'x':int,'y':float}, limit=100)
plot = perspective.PerspectiveWidget(table,sort=['x','asc'], plugin="X/Y Line")
plot2 = perspective.PerspectiveWidget(table,sort=['x','asc'], plugin="X/Y Line")
grid[5:10,:]=plot
grid[11:15,:]=plot2

grid
# Out:
# GridspecLayout(children=(BoundedIntText(value=100, description='Text:', layout=Layout(grid_area='widget001'), …

# %%
i = 0
while True:
    table.update({"x":[i],"y":[psutil.cpu_percent()]})
    table.view().to_df()
    time.sleep(.5)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       3 table.update({"x":[i],"y":[psutil.cpu_percent()]})
#       4 table.view().to_df()
# ----> 5 time.sleep(.5)
#       6 i+=1
#
# KeyboardInterrupt:
